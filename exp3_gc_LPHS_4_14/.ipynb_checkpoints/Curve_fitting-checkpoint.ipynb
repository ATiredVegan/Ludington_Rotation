# %%
import numpy as np
import random
import math
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt 
from scipy.optimize import curve_fit
import pandas as pd
import seaborn as sns; sns.set()

# %% [markdown]
# # Curve Fitting for L. Plantarum GFP/mCherry
# 1. Define sigmoid function in two forms
# 2. Fit data to sigmoid function to find r and k values
# 3. Find dilution rate/or threshold time to keep OD basically constant

# %%
#Defining logistic function
def sigmoid(x, L, x0, k):
     y = L / (1 + np.exp(-k*(x-x0)))
     return y
#Defining logistic function, but in log form
def log_sigmoid(x,L,x0,k):
    y=math.log(L)-math.log(np.exp(-k*(math.log(x)-x0)))
    return y

# %%
data1=pd.read_excel("4_7_lp_gc1.xlsx")

data2
plate=pd.read_excel("4_7_exp1_plate.xlsx",index_col=0)
order=['Time','Temp']
for well in plate.itertuples():
    for entry in well[1:]:
        order.append(entry)
print(order)
data1.columns=order
data2.columns=order
data1
# Out:
# ['Time', 'Temp', 'GFP1 1x', 'GFP1 1x', 'GFP1 1x', 'GFP2 1x', 'GFP2 1x', 'GFP2 1x', 'GFP3 1x', 'GFP3 1x', 'GFP3 1x', '1x Media', '1x Media', '1x Media', 'MC1 1x', 'MC1 1x', 'MC1 1x', 'MC2 1x', 'MC2 1x', 'MC2 1x', 'MC3 1x', 'MC3 1x', 'MC3 1x', '1x Media', '1x Media', '1x Media', 'GFP1 6x', 'GFP1 6x', 'GFP1 6x', 'GFP2 6x', 'GFP2 6x', 'GFP2 6x', 'GFP3 6x', 'GFP3 6x', 'GFP3 6x', '6x Media', '6x Media', '6x Media', 'MC1 6x', 'MC1 6x', 'MC1 6x', 'MC2 6x', 'MC2 6x', 'MC2 6x', 'MC3 6x', 'MC3 6x', 'MC3 6x', '6x Media', '6x Media', '6x Media', 'GFP1 36x', 'GFP1 36x', 'GFP1 36x', 'GFP2 36x', 'GFP2 36x', 'GFP2 36x', 'GFP3 36x', 'GFP3 36x', 'GFP3 36x', '36x Media', '36x Media', '36x Media', 'MC1 36x', 'MC1 36x', 'MC1 36x', 'MC2 36x', 'MC2 36x', 'MC2 36x', 'MC3 36x', 'MC3 36x', 'MC3 36x', '36x Media', '36x Media', '36x Media', 'GFP1 180x', 'GFP1 180x', 'GFP1 180x', 'GFP2 180x', 'GFP2 180x', 'GFP2 180x', 'GFP3 180x', 'GFP3 180x', 'GFP3 180x', '180x Media', '180x Media', '180x Media', 'MC1 180x', 'MC1 180x', 'MC1 180x', 'MC2 180x', 'MC2 180x', 'MC2 180x', 'MC3 180x', 'MC3 180x', 'MC3 180x', '180x Media', '180x Media', '180x Media']
#          Time  Temp  GFP1 1x  GFP1 1x  GFP1 1x  GFP2 1x  GFP2 1x  GFP2 1x  \
# 0    00:04:16  25.2    0.171    0.178    0.185    0.181    0.180    0.189
# 1    00:09:16  25.2    0.176    0.181    0.190    0.186    0.184    0.192
# 2    00:14:16  25.3    0.179    0.185    0.193    0.190    0.189    0.194
# 3    00:19:16  25.3    0.183    0.187    0.196    0.192    0.192    0.197
# 4    00:24:16  25.3    0.187    0.190    0.200    0.196    0.194    0.200
# ..        ...   ...      ...      ...      ...      ...      ...      ...
# 255  21:19:16  26.0    1.717    1.730    1.773    1.769    1.768    1.752
# 256  21:24:16  26.0    1.717    1.731    1.774    1.770    1.768    1.753
# 257  21:29:16  26.0    1.717    1.731    1.774    1.769    1.768    1.753
# 258  21:34:16  26.0    1.718    1.732    1.774    1.770    1.769    1.753
# 259  21:39:16  25.9    1.717    1.731    1.774    1.769    1.767    1.754
#
#      GFP3 1x  GFP3 1x  ...  MC1 180x  MC2 180x  MC2 180x  MC2 180x  MC3 180x  \
# 0      0.183    0.181  ...     0.108     0.101     0.103     0.097     0.106
# 1      0.186    0.184  ...     0.107     0.101     0.103     0.097     0.106
# 2      0.190    0.186  ...     0.107     0.102     0.103     0.097     0.105
# 3      0.193    0.190  ...     0.109     0.101     0.103     0.097     0.105
# 4      0.195    0.193  ...     0.105     0.101     0.103     0.097     0.105
# ..       ...      ...  ...       ...       ...       ...       ...       ...
# 255    1.795    1.778  ...     0.106     0.103     0.105     0.099     0.102
# 256    1.794    1.778  ...     0.104     0.103     0.105     0.098     0.102
# 257    1.795    1.778  ...     0.108     0.103     0.105     0.099     0.104
# 258    1.796    1.778  ...     0.103     0.103     0.104     0.099     0.102
# 259    1.795    1.778  ...     0.103     0.103     0.104     0.098     0.102
#
#      MC3 180x  MC3 180x  180x Media  180x Media  180x Media
# 0       0.103     0.102       0.103       0.104       0.099
# 1       0.103     0.102       0.103       0.104       0.098
# 2       0.103     0.102       0.103       0.104       0.098
# 3       0.102     0.102       0.103       0.104       0.098
# 4       0.102     0.102       0.103       0.104       0.098
# ..        ...       ...         ...         ...         ...
# 255     0.100     0.100       0.099       0.098       0.096
# 256     0.100     0.100       0.099       0.098       0.096
# 257     0.100     0.100       0.099       0.098       0.096
# 258     0.100     0.100       0.099       0.098       0.096
# 259     0.100     0.100       0.099       0.098       0.096
#
# [260 rows x 98 columns]

# %%
samples=['GFP1','GFP2','GFP3','MC1','MC2','MC3']
dilutions=['1x','6x','36x','180x']
for sample in samples:
    for dilution in dilutions:
        data1['NormAve '+sample+' '+dilution]=(data1[sample+' '+dilution].mean(axis=1)-data1[dilution+ ' Media'].mean(axis=1)+data2[sample+' '+dilution].mean(axis=1)-data2[dilution+' Media'].mean(axis=1))/2
data1['Time']=[5*x for x in range(0,260)]

# %%
r_vals={}
k_vals={}
threshold_time={}
fig, ax = plt.subplots(1,1,figsize=(15,15), sharex=True, sharey=True) 
for sample in samples:
    for dilution in dilutions[:-2]:
        x_vals=data1['Time'].values
        y_vals=data1['NormAve '+sample+' '+dilution].values 
        ax.plot(data1['Time'],data1['NormAve '+sample+' '+dilution], 'o',label='NormAve '+sample+' '+dilution)
        #gets fit
        try:
            popt, pcov = curve_fit(sigmoid,x_vals,y_vals, p0=[0.5,1000,0.01])
        except RuntimeError:
            pass
        
        r_vals[sample+' '+dilution]=popt[2]
        k_vals[sample+' '+dilution]=popt[0]
        try:
            threshold_time[sample+' '+dilution]=5*data1[data1['NormAve '+sample+' '+dilution].gt(0.05)].index[0]
        except IndexError:
            threshold_time[sample+' '+dilution]=5
        fitted_y=sigmoid(x_vals,*popt)
        ax.plot(x_vals,fitted_y,label="fitted "+sample+' '+dilution)
ax.legend(loc='lower right')
ax.set_xlabel("Time (min)")
ax.set_ylabel("OD600")
ax.set(title='Growth Rate of L Plantarum on diluted media')
# Out:
# [Text(0.5,1,'Growth Rate of L Plantarum on diluted media')]

# %%
print(r_vals)
print(k_vals)
print(threshold_time)
doubling_time={}
for r_val in r_vals:
    doubling_time[r_val]=np.log(2)/(r_vals[r_val])
print(doubling_time)
# Out:
# {'GFP1 1x': 0.007458759102106363, 'GFP1 6x': 0.004979397768458209, 'GFP2 1x': 0.007916163934392585, 'GFP2 6x': 0.00463351456646452, 'GFP3 1x': 0.008052328268867377, 'GFP3 6x': 0.004818096784405224, 'MC1 1x': 0.00706490026388376, 'MC1 6x': 0.0065119940505820005, 'MC2 1x': 0.007212043706528928, 'MC2 6x': 0.005974088068778291, 'MC3 1x': 0.0073413547620745385, 'MC3 6x': 0.006265364715253912}
# {'GFP1 1x': 1.6310338701131537, 'GFP1 6x': 1.537117788501771, 'GFP2 1x': 1.6475902469876784, 'GFP2 6x': 1.5936045904323575, 'GFP3 1x': 1.6634734670702982, 'GFP3 6x': 1.6278602030517637, 'MC1 1x': 1.640209430342001, 'MC1 6x': 1.1841058189279154, 'MC2 1x': 1.650795810300808, 'MC2 6x': 1.392131963958011, 'MC3 1x': 1.6391603263451, 'MC3 6x': 1.2249593117595996}
# {'GFP1 1x': 0, 'GFP1 6x': 150, 'GFP2 1x': 0, 'GFP2 6x': 140, 'GFP3 1x': 0, 'GFP3 6x': 130, 'MC1 1x': 30, 'MC1 6x': 315, 'MC2 1x': 5, 'MC2 6x': 180, 'MC3 1x': 0, 'MC3 6x': 225}
# {'GFP1 1x': 92.93062975638932, 'GFP1 6x': 139.2030146598566, 'GFP2 1x': 87.56099372178188, 'GFP2 6x': 149.5942595231405, 'GFP3 1x': 86.08034315240874, 'GFP3 6x': 143.86327456174413, 'MC1 1x': 98.1113893572369, 'MC1 6x': 106.44161760221452, 'MC2 1x': 96.10967553239482, 'MC2 6x': 116.02560467470558, 'MC3 1x': 94.41679404198607, 'MC3 6x': 110.63157726035979}
